# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Ising

# %%
Ising_vqls_file = '../Ising/4qubit/'

ising_vqls = []
for i in range(1,11):
    fname = Ising_vqls_file + f'Ising_4qubits_60kappa_10000shots_{i}seed_fidelity_Powell.txt'

    with open(fname, 'r') as f:
        count = 0
        for val in f.readlines():
            if float(val[1:-5]) > 0.99:
                break
            count += 1
        ising_vqls.append(count)

ising_vqls_avg = np.mean(ising_vqls)
ising_vqls_std = np.std(ising_vqls)

ising_vqls_avg, ising_vqls_std
# Out:
# (np.float64(35.7), np.float64(4.360045871318328))

# %%
Ising_sls_file = '../Ising/4qubit/'
ising_sls = []

for i in range(1,11):
    fname = Ising_sls_file + f'Ising_4qubits_0.01serr_fidelity_{i}seed_Powell.txt'
    
    with open(fname, 'r') as f:
        count = 0
        for val in f.readlines():
            if float(val[1:-5]) > 0.99:
                break
            count += 1

    ising_sls.append(count)    
    
ising_sls_avg = np.mean(ising_sls)
ising_sls_std = np.std(ising_sls)
ising_sls_avg, ising_sls_std
# Out:
# (np.float64(34.4), np.float64(4.882622246293481))

# %% [markdown]
# # Potential

# %%
Potential_vqls_file = '../PGLS/4qubit/'

potential_vqls = []
for i in range(1,11):
    fname = Potential_vqls_file + f'Potential_4qubits_900shots_fidelity_{i}seed_Adam.txt'

    with open(fname, 'r') as f:
        count = 0
        for val in f.readlines():
            if float(val[1:-5]) > 0.99:
                break
            count += 1

    potential_vqls.append(count)      

potential_vqls_avg = np.mean(np.array(potential_vqls))
potential_vqls_std = np.std(np.array(potential_vqls))

potential_vqls_avg, potential_vqls_std
# Out:
# (np.float64(149.7), np.float64(30.6073520579615))

# %%
Potential_sls_file = '../PGLS/4qubit/'

potential_sls = []
for i in range(1,11):
    fname = Potential_sls_file + f'Potential_4qubits_0.03serr_fidelity_{i}seed_Adam.txt'
    
    with open(fname, 'r') as f:
        count = 0
        for val in f.readlines():
            if float(val[1:-5]) > 0.99:
                break
            count += 1

    potential_sls.append(count)    

potential_sls_avg = np.mean(np.array(potential_sls))
potential_sls_std = np.std(np.array(potential_sls))

potential_sls_avg, potential_sls_std
# Out:
# (np.float64(94.2), np.float64(3.5156791662493894))

# %% [markdown]
# # Random 1

# %%
Random1_vqls_file = '../RQLSP1/4qubit/'

random_vqls = []
for i in range(1,11): 
    fname = Random1_vqls_file + f'Random_4qubits_10kappa_900shots_{i}seed_fidelity_Adam.txt'

    with open(fname, 'r') as f:
        count = 0
        for val in f.readlines():
            if float(val[1:-5]) > 0.9:
                break
            count += 1
    random_vqls.append(count)

random_vqls_avg = np.mean(np.array(random_vqls))
random_vqls_std = np.std(np.array(random_vqls))

random_vqls_avg, random_vqls_std
# Out:
# (np.float64(133.1), np.float64(22.1153792642134))

# %%
# SQLS
Random_sls_file = '../RQLSP1/4qubit/'

random_sls = []
for i in range(1,11):
    fname = Random_sls_file + f'Random1_4qubits_0.03serr_fidelity_{i}seed_Adam.txt'

    with open(fname, 'r') as f:
        count = 0
        for val in f.readlines():
            if float(val[1:-5]) > 0.9:
                break
            count += 1
    random_sls.append(count)

random_sls_avg = np.mean(np.array(random_sls))
random_sls_std = np.std(np.array(random_sls))

random_sls_avg, random_sls_std
# Out:
# (np.float64(81.6), np.float64(2.7640549922170505))

# %% [markdown]
# # Random 2

# %%
Random2_vqls_file = '../RQLSP2/4qubit/0.15err/'

random2_vqls = []
for i in range(1,11): 
    fname = Random2_vqls_file + f'Random2_4qubits_10kappa_900shots_{i}seed_fidelity_Adam.txt'

    with open(fname, 'r') as f:
        count = 0
        for val in f.readlines():
            if float(val[1:-5]) > 0.85:
                break
            count += 1

    random2_vqls.append(count)

random2_vqls_avg = np.mean(np.array(random2_vqls))
random2_vqls_std = np.std(np.array(random2_vqls))

random2_vqls_avg, random2_vqls_std
# Out:
# (np.float64(56.3), np.float64(4.583666654546336))

# %%
# SQLS
Random2_sls_file = '../RQLSP2/4qubit/0.15err/'

random2_sls = []
for i in range(1,11):
    fname = Random2_sls_file + f'Random2_4qubits_0.03serr_fidelity_{i}seed_Adam.txt'

    with open(fname, 'r') as f:
        count = 0
        for val in f.readlines():
            if float(val[1:-5]) > 0.85:
                break
            count += 1
    random2_sls.append(count)


random2_sls_avg = np.mean(np.array(random2_sls))
random2_sls_std = np.std(np.array(random2_sls))

random2_sls_avg, random2_sls_std
# Out:
# (np.float64(47.7), np.float64(3.7960505792204615))

# %% [markdown]
# # Bar graph

# %%
color = ['#aadce0',
 '#ef8a47',
 '#376795',
 '#f7aa58',
 '#72bcd5',
 '#ffe6b7',
 '#e76254',
 '#1e466e',
 '#ffd06f',
 '#528fad']

# %%
plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.sans-serif": "Palatino",})

plt.figure(figsize=(3.5,2.75))

barWidth = 0.25

sls = [ising_sls_avg, potential_sls_avg, random_sls_avg, random2_sls_avg]
sls_std = [ising_sls_std, potential_sls_std, random_sls_std, random2_sls_std] 

vqls = [ising_vqls_avg, potential_vqls_avg, random_vqls_avg, random2_vqls_avg]
vqls_std = [ising_vqls_std, potential_vqls_std, random_vqls_std, random2_vqls_std]

br1 = np.arange(len(sls)) 
br2 = [x + barWidth for x in br1] 

plt.bar(br1, sls, color ='#1081C1', width = barWidth, 
        edgecolor ='grey', label ='SQLS', yerr = sls_std)
plt.bar(br2, vqls, color ='#e76254', width = barWidth, 
        edgecolor ='grey', label ='VQLS', yerr = vqls_std)

plt.xticks([r + barWidth/2 for r in range(4)], 
        ['IQLSP', 'PGLS', 'RQLSP 1', 'RQLSP 2'])

plt.xlabel(r' ')
plt.ylabel(r'time-to-solution', fontsize = 11, labelpad=12, va = 'center')
plt.ticklabel_format(axis='y', style='sci')
plt.yticks(fontsize = 8)
plt.xticks(fontsize = 8)

plt.legend(loc='upper left', borderaxespad=0, fontsize = 8, labelspacing = 0.35)
plt.savefig('tts_problem_FINAL.pdf', bbox_inches = 'tight')
